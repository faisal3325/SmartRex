# %%
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sprite = cv2.imread('sprite.png')
print(sprite.shape)
roi = sprite[0:100, 1680:1763]

plt.imshow(roi)
# Out:
# (130, 2446, 3)

# %%
sprite = cv2.imread('sprite.png')
print(sprite.shape)
roi = sprite[0:80, 445:520]

plt.imshow(roi)
# Out:
# (130, 2446, 3)
